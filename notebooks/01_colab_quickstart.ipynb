# %% [markdown]
# # World Cup 2026 Predictor - Colab Quick Start
#
# Use this notebook to run the project in Google Colab. The project is intentionally CPU-friendly: no deep learning, no AutoML, and no heavy grid search.

# %% [markdown]
# ## Setup
#
# In Colab, uncomment and run the clone/install cells once.

# %%
# !git clone https://github.com/wdqgallego-git/worldcup-predictor.git
# %cd worldcup-predictor
# !pip install -r requirements.txt

# %%
import sys
from pathlib import Path

project_root = Path.cwd()
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from worldcup_predictor.config import SimulationConfig
from worldcup_predictor.format_2026 import default_format

config = SimulationConfig(n_simulations=1000)
tournament_format = default_format()

config.validate()
tournament_format.validate()

print(config)
print(tournament_format)

# %% [markdown]
# ## Next Steps
#
# Implement each module step by step: data inputs, ratings, match model, tournament simulation, awards, strategy, calibration, and backtesting.
